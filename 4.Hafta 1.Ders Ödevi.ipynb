# %%
import pandas as pd

# %%
sozluk = {"Kategori": ["Giyim","Giyim", "Ayakkabı","Aksesuar","Ayakkabı","Giyim","Aksesuar","Aksesuar","Ayakkabı","Giyim"],
          
          "Ürün" : ["Kazak","T-shirt","Sandalet","Küpe","Spor Ayakkabı","Pantolon","Kolye","Yüzük","Çizme","Ceket"],

          "Fiyat" : [300,180,450,50,700,400,150,80,850,900]}

# %%
a=pd.DataFrame(sozluk,columns=["Kategori","Ürün","Fiyat"])
a
# Out:
#    Kategori           Ürün  Fiyat
# 0     Giyim          Kazak    300
# 1     Giyim        T-shirt    180
# 2  Ayakkabı       Sandalet    450
# 3  Aksesuar           Küpe     50
# 4  Ayakkabı  Spor Ayakkabı    700
# 5     Giyim       Pantolon    400
# 6  Aksesuar          Kolye    150
# 7  Aksesuar          Yüzük     80
# 8  Ayakkabı          Çizme    850
# 9     Giyim          Ceket    900

# %%
a[["Kategori"]]
# Out:
#    Kategori
# 0     Giyim
# 1     Giyim
# 2  Ayakkabı
# 3  Aksesuar
# 4  Ayakkabı
# 5     Giyim
# 6  Aksesuar
# 7  Aksesuar
# 8  Ayakkabı
# 9     Giyim

# %%
a[2:3][["Kategori"]]
# Out:
#    Kategori
# 2  Ayakkabı

# %%
a[2:3][["Ürün"]]
# Out:
#        Ürün
# 2  Sandalet

# %%
a[4:9]
# Out:
#    Kategori           Ürün  Fiyat
# 4  Ayakkabı  Spor Ayakkabı    700
# 5     Giyim       Pantolon    400
# 6  Aksesuar          Kolye    150
# 7  Aksesuar          Yüzük     80
# 8  Ayakkabı          Çizme    850

# %%
a[1:6][["Ürün"]]
# Out:
#             Ürün
# 1        T-shirt
# 2       Sandalet
# 3           Küpe
# 4  Spor Ayakkabı
# 5       Pantolon

# %%
a
# Out:
#    Kategori           Ürün  Fiyat
# 0     Giyim          Kazak    300
# 1     Giyim        T-shirt    180
# 2  Ayakkabı       Sandalet    450
# 3  Aksesuar           Küpe     50
# 4  Ayakkabı  Spor Ayakkabı    700
# 5     Giyim       Pantolon    400
# 6  Aksesuar          Kolye    150
# 7  Aksesuar          Yüzük     80
# 8  Ayakkabı          Çizme    850
# 9     Giyim          Ceket    900

# %%
a[a["Kategori"]=="Giyim"]
# Out:
#   Kategori      Ürün  Fiyat
# 0    Giyim     Kazak    300
# 1    Giyim   T-shirt    180
# 5    Giyim  Pantolon    400
# 9    Giyim     Ceket    900

# %%
a[a["Kategori"]=="Ayakkabı"]
# Out:
#    Kategori           Ürün  Fiyat
# 2  Ayakkabı       Sandalet    450
# 4  Ayakkabı  Spor Ayakkabı    700
# 8  Ayakkabı          Çizme    850

# %%
a[a["Kategori"]=="Aksesuar"]
# Out:
#    Kategori   Ürün  Fiyat
# 3  Aksesuar   Küpe     50
# 6  Aksesuar  Kolye    150
# 7  Aksesuar  Yüzük     80

# %%
a[(a["Kategori"]=="Giyim")&(a["Fiyat"]>300)]
# Out:
#   Kategori      Ürün  Fiyat
# 5    Giyim  Pantolon    400
# 9    Giyim     Ceket    900

# %%
a[(a["Kategori"]=="Ayakkabı")&(a["Fiyat"]<600)]
# Out:
#    Kategori      Ürün  Fiyat
# 2  Ayakkabı  Sandalet    450

# %%
a[(a["Kategori"]=="Aksesuar")&(a["Fiyat"]>100)]
# Out:
#    Kategori   Ürün  Fiyat
# 6  Aksesuar  Kolye    150
