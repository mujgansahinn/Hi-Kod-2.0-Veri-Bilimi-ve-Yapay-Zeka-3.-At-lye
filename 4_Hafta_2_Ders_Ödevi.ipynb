# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv("StudentsPerformance.csv")
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
a.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
a["gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
b=a["gender"].value_counts()
b
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sns.histplot(x="gender",data=a)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
a["race/ethnicity"].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
b=a["race/ethnicity"].value_counts()
b
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
sns.barplot(x=b.index,y=b.values)
plt.title("Gruplardaki öğrenci dağılımları")
plt.xlabel("Gruplar")
plt.ylabel("Öğrenci sayısı")
# Out:
# Text(0, 0.5, 'Öğrenci sayısı')

# %%
a["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
a["parental level of education"].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
a["lunch"].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
a["lunch"].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
a["test preparation course"].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
a.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
a.groupby("gender")[["math score","reading score","writing score"]].mean().reset_index()
# Out:
#    gender  math score  reading score  writing score
# 0  female   63.633205      72.608108      72.467181
# 1    male   68.728216      65.473029      63.311203

# %%
a.groupby("race/ethnicity")[["math score","reading score","writing score"]].mean().reset_index()
# Out:
#   race/ethnicity  math score  reading score  writing score
# 0        group A   61.629213      64.674157      62.674157
# 1        group B   63.452632      67.352632      65.600000
# 2        group C   64.463950      69.103448      67.827586
# 3        group D   67.362595      70.030534      70.145038
# 4        group E   73.821429      73.028571      71.407143

# %%
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
a.groupby("parental level of education")[["math score","reading score","writing score"]].mean().reset_index()
# Out:
#   parental level of education  math score  reading score  writing score
# 0          associate's degree   67.882883      70.927928      69.896396
# 1           bachelor's degree   69.389831      73.000000      73.381356
# 2                 high school   62.137755      64.704082      62.448980
# 3             master's degree   69.745763      75.372881      75.677966
# 4                some college   67.128319      69.460177      68.840708
# 5            some high school   63.497207      66.938547      64.888268

# %%
a.groupby("lunch")[["math score","reading score","writing score"]].mean().reset_index()
# Out:
#           lunch  math score  reading score  writing score
# 0  free/reduced   58.921127      64.653521      63.022535
# 1      standard   70.034109      71.654264      70.823256

# %%
a.groupby("test preparation course")[["math score","reading score","writing score"]].mean().reset_index()
# Out:
#   test preparation course  math score  reading score  writing score
# 0               completed   69.695531      73.893855      74.418994
# 1                    none   64.077882      66.534268      64.504673
